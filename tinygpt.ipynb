# %%
# !pip install einops
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset text downloaded and prepared to data/torch/text/default-268a7bb69ffead3e/0.0.0/4b86d314f7236db91f0a0f5cda32d4375445e64c5eda2692655dd99c2dac68e8. Subsequent calls will reuse this data.
# ...
#   Progress  |   Epoch    |   Batch    | Batch Time |   loss:0
# ------------|------------|------------|------------|------------
#
#    0.22%    |     1      |     1      |  12.613s   |  11.3383
#    0.43%    |     1      |     2      |   9.315s   |  10.1490
#    0.65%    |     1      |     3      |   7.343s   |   9.4729
#    0.86%    |     1      |     4      |   8.012s   |   9.3488

# %%
import sys
sys.path.append('/kaggle/input/aitoolkit')

from examples.text.RomeArena import TrainRoles, RunRoles
roles = [
    'Dragonfly-70m'
]
TrainRoles(roles, data_dir='/kaggle/input/bookcorpus/books1/epubtxt', model_dir='/kaggle/input/aitoolkit/data/pretrain', save_dir='/kaggle/working', lr = 6e-3, epochs=1)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 8
#       4 from examples.text.RomeArena import TrainRoles, RunRoles
#       5 roles = [
#       6     'Dragonfly-70m'
#       7 ]
# ----> 8 TrainRoles(roles, data_dir='/kaggle/input/bookcorpus', model_dir='/kaggle/input/aitoolkit/data/pretrain', save_dir='/kaggle/working', lr = 6e-3, epochs=1)
#
# File /kaggle/input/aitoolkit/examples/text/RomeArena.py:50, in TrainRoles(roles, data_dir, model_dir, save_dir, batch_size, lr, epochs)
#      47     role.persist_filename = f"{save_dir}/{role.name}.ckt"
#      49 # -- Data loader
# ---> 50 dataset = repo.AutoDataset('text', data_dir=data_dir, split='train')
#      51 dataloader = aka.data.TextStreamingLoader(
#      52                 dataset,
# ...
